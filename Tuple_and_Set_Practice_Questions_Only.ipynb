# %% [markdown]
# # Python Practice: Tuple and Set (Practice Only)
#
# This notebook contains **practice questions only** on **Tuples** and **Sets**.
#
# Instructions:
# - Questions are written in **text cells**
# - Write your solution in the **code cell below each question**
# - Do NOT use any advanced concepts

# %% [markdown]
# ##  Tuple Practice Questions

# %% [markdown]
# ### Question 1
# Create a tuple of 5 integers and print it.

# %%
tup1=41,23,45,65,67
print(tup1)
print(type(tup1))

# %% [markdown]
# ### Question 2
# Create a tuple with different data types (int, float, string, boolean) and print each element separately.

# %%
tuple1 = ("abc", 34, True, 40, "male")
print(tuple1)
print(type(tup1))
# Out:
# ('abc', 34, True, 40, 'male')

# %% [markdown]
# ### Question 3
# Find the length of a tuple containing names of 4 students.

# %%
tuple=("shivam","paranay","mavi","aditi")
print(len(tuple))
# Out:
# 4

# %% [markdown]
# ### Question 4
# Access and print the last element of a tuple.

# %%
tuple1 = ("abc", 34, True, 40, "male")
print(tuple1[-1])
# Out:
# male

# %% [markdown]
# ### Question 5
# Check whether an element exists in a tuple or not.

# %%
tuple=("shivam","paranay","mavi","aditi")
if "shivam" in tuple:
    print("yes")
else:
    print("no")
# Out:
# yes

# %% [markdown]
# ### Question 6
# Convert a tuple into a list.

# %%
tuple=("shivam","paranay","mavi","aditi")
my_list=list(tuple)
print(my_list)
# Out:
# ['shivam', 'paranay', 'mavi', 'aditi']

# %% [markdown]
# ### Question 7
# Convert a list into a tuple.

# %%
my_list1 = ["abc", 34, True, 40, "male"]
my_tuple = tuple(my_list1)
print(my_tuple)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-464362256.py in <cell line: 0>()
#       1 my_list1 = ["abc", 34, True, 40, "male"]
# ----> 2 my_tuple = tuple(my_list1)
#       3 print(my_tuple)
#
# TypeError: 'tuple' object is not callable

# %% [markdown]
# ### Question 8
# Create a tuple with repeated values and count how many times an element appears.

# %%
tup1=1,2,4,2,6,8,2,1,1,1
print(tup1.count(1))
# Out:
# 4

# %% [markdown]
# ### Question 9
# Find the index of an element in a tuple.

# %%
tuple1 = ("abc", 34, True, 40, "male")
print(tuple1.index(34))
# Out:
# 1

# %% [markdown]
# ### Question 10
# Demonstrate that tuples are immutable (cannot be changed).

# %%
my_tuple = (10, 20, 30)
my_tuple = (10, 20, 30, 40)
print(my_tuple)
# Out:
# (10, 20, 30, 40)
